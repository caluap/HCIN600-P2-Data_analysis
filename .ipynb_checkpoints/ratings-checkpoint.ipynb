# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install trueskill
# Out:
# Requirement already satisfied: trueskill in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (0.4.5)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from trueskill) (1.15.0)
# WARNING: You are using pip version 19.3.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import trueskill

# %% [markdown]
# # simple test

# %%
r1 = trueskill.Rating()
r2 = trueskill.Rating()

for i in range(100):
  print(r1)
  print(r2)
  print('------\n\n\n')  
  r1, r2 = trueskill.rate_1vs1(r1, r2)
# Out:
# trueskill.Rating(mu=25.000, sigma=8.333)
# trueskill.Rating(mu=25.000, sigma=8.333)
# ------
#
#
#
# trueskill.Rating(mu=29.396, sigma=7.171)
# trueskill.Rating(mu=20.604, sigma=7.171)
# ------
#
#
#
# trueskill.Rating(mu=31.230, sigma=6.523)
# trueskill.Rating(mu=18.770, sigma=6.523)
# ------
#
#
#
# trueskill.Rating(mu=32.249, sigma=6.106)
# trueskill.Rating(mu=17.751, sigma=6.106)
# ------
#
#
#
# trueskill.Rating(mu=32.910, sigma=5.809)
# trueskill.Rating(mu=17.090, sigma=5.809)
# ------
#
#
#
# trueskill.Rating(mu=33.380, sigma=5.585)
# trueskill.Rating(mu=16.620, sigma=5.585)
# ------
#
#
#
# trueskill.Rating(mu=33.735, sigma=5.408)
# trueskill.Rating(mu=16.265, sigma=5.408)
# ------
#
#
#
# trueskill.Rating(mu=34.016, sigma=5.263)
# trueskill.Rating(mu=15.984, sigma=5.263)
# ------
#
#
#
# trueskill.Rating(mu=34.246, sigma=5.141)
# trueskill.Rating(mu=15.754, sigma=5.141)
# ------
#
#
#
# trueskill.Rating(mu=34.438, sigma=5.037)
# trueskill.Rating(mu=15.562, sigma=5.037)
# ------
#
#
#
# trueskill.Rating(mu=34.602, sigma=4.947)
# trueskill.Rating(mu=15.398, sigma=4.947)
# ------
#
#
#
# trueskill.Rating(mu=34.744, sigma=4.867)
# trueskill.Rating(mu=15.256, sigma=4.867)
# ------
#
#
#
# trueskill.Rating(mu=34.869, sigma=4.796)
# trueskill.Rating(mu=15.131, sigma=4.796)
# ------
#
#
#
# trueskill.Rating(mu=34.981, sigma=4.732)
# trueskill.Rating(mu=15.019, sigma=4.732)
# ------
#
#
#
# trueskill.Rating(mu=35.080, sigma=4.675)
# trueskill.Rating(mu=14.920, sigma=4.675)
# ------
#
#
#
# trueskill.Rating(mu=35.171, sigma=4.622)
# trueskill.Rating(mu=14.829, sigma=4.622)
# ------
#
#
#
# trueskill.Rating(mu=35.253, sigma=4.574)
# trueskill.Rating(mu=14.747, sigma=4.574)
# ------
#
#
#
# trueskill.Rating(mu=35.328, sigma=4.529)
# trueskill.Rating(mu=14.672, sigma=4.529)
# ------
#
#
#
# trueskill.Rating(mu=35.398, sigma=4.488)
# trueskill.Rating(mu=14.602, sigma=4.488)
# ------
#
#
#
# trueskill.Rating(mu=35.462, sigma=4.449)
# trueskill.Rating(mu=14.538, sigma=4.449)
# ------
#
#
#
# trueskill.Rating(mu=35.522, sigma=4.414)
# trueskill.Rating(mu=14.478, sigma=4.414)
# ------
#
#
#
# trueskill.Rating(mu=35.577, sigma=4.380)
# trueskill.Rating(mu=14.423, sigma=4.380)
# ------
#
#
#
# trueskill.Rating(mu=35.630, sigma=4.348)
# trueskill.Rating(mu=14.370, sigma=4.348)
# ------
#
#
#
# trueskill.Rating(mu=35.679, sigma=4.319)
# trueskill.Rating(mu=14.321, sigma=4.319)
# ------
#
#
#
# trueskill.Rating(mu=35.725, sigma=4.290)
# trueskill.Rating(mu=14.275, sigma=4.290)
# ------
#
#
#
# trueskill.Rating(mu=35.769, sigma=4.264)
# trueskill.Rating(mu=14.231, sigma=4.264)
# ------
#
#
#
# trueskill.Rating(mu=35.810, sigma=4.239)
# trueskill.Rating(mu=14.190, sigma=4.239)
# ------
#
#
#
# trueskill.Rating(mu=35.849, sigma=4.215)
# trueskill.Rating(mu=14.151, sigma=4.215)
# ------
#
#
#
# trueskill.Rating(mu=35.887, sigma=4.192)
# trueskill.Rating(mu=14.113, sigma=4.192)
# ------
#
#
#
# trueskill.Rating(mu=35.922, sigma=4.170)
# trueskill.Rating(mu=14.078, sigma=4.170)
# ------
#
#
#
# trueskill.Rating(mu=35.956, sigma=4.149)
# trueskill.Rating(mu=14.044, sigma=4.149)
# ------
#
#
#
# trueskill.Rating(mu=35.989, sigma=4.129)
# trueskill.Rating(mu=14.011, sigma=4.129)
# ------
#
#
#
# trueskill.Rating(mu=36.020, sigma=4.110)
# trueskill.Rating(mu=13.980, sigma=4.110)
# ------
#
#
#
# trueskill.Rating(mu=36.050, sigma=4.091)
# trueskill.Rating(mu=13.950, sigma=4.091)
# ------
#
#
#
# trueskill.Rating(mu=36.078, sigma=4.074)
# trueskill.Rating(mu=13.922, sigma=4.074)
# ------
#
#
#
# trueskill.Rating(mu=36.106, sigma=4.057)
# trueskill.Rating(mu=13.894, sigma=4.057)
# ------
#
#
#
# trueskill.Rating(mu=36.133, sigma=4.040)
# trueskill.Rating(mu=13.867, sigma=4.040)
# ------
#
#
#
# trueskill.Rating(mu=36.158, sigma=4.025)
# trueskill.Rating(mu=13.842, sigma=4.025)
# ------
#
#
#
# trueskill.Rating(mu=36.183, sigma=4.009)
# trueskill.Rating(mu=13.817, sigma=4.009)
# ------
#
#
#
# trueskill.Rating(mu=36.207, sigma=3.995)
# trueskill.Rating(mu=13.793, sigma=3.995)
# ------
#
#
#
# trueskill.Rating(mu=36.230, sigma=3.980)
# trueskill.Rating(mu=13.770, sigma=3.980)
# ------
#
#
#
# trueskill.Rating(mu=36.252, sigma=3.967)
# trueskill.Rating(mu=13.748, sigma=3.967)
# ------
#
#
#
# trueskill.Rating(mu=36.274, sigma=3.953)
# trueskill.Rating(mu=13.726, sigma=3.953)
# ------
#
#
#
# trueskill.Rating(mu=36.295, sigma=3.940)
# trueskill.Rating(mu=13.705, sigma=3.940)
# ------
#
#
#
# trueskill.Rating(mu=36.315, sigma=3.928)
# trueskill.Rating(mu=13.685, sigma=3.928)
# ------
#
#
#
# trueskill.Rating(mu=36.335, sigma=3.916)
# trueskill.Rating(mu=13.665, sigma=3.916)
# ------
#
#
#
# trueskill.Rating(mu=36.354, sigma=3.904)
# trueskill.Rating(mu=13.646, sigma=3.904)
# ------
#
#
#
# trueskill.Rating(mu=36.373, sigma=3.892)
# trueskill.Rating(mu=13.627, sigma=3.892)
# ------
#
#
#
# trueskill.Rating(mu=36.391, sigma=3.881)
# trueskill.Rating(mu=13.609, sigma=3.881)
# ------
#
#
#
# trueskill.Rating(mu=36.409, sigma=3.870)
# trueskill.Rating(mu=13.591, sigma=3.870)
# ------
#
#
#
# trueskill.Rating(mu=36.426, sigma=3.860)
# trueskill.Rating(mu=13.574, sigma=3.860)
# ------
#
#
#
# trueskill.Rating(mu=36.443, sigma=3.850)
# trueskill.Rating(mu=13.557, sigma=3.850)
# ------
#
#
#
# trueskill.Rating(mu=36.459, sigma=3.840)
# trueskill.Rating(mu=13.541, sigma=3.840)
# ------
#
#
#
# trueskill.Rating(mu=36.475, sigma=3.830)
# trueskill.Rating(mu=13.525, sigma=3.830)
# ------
#
#
#
# trueskill.Rating(mu=36.491, sigma=3.820)
# trueskill.Rating(mu=13.509, sigma=3.820)
# ------
#
#
#
# trueskill.Rating(mu=36.506, sigma=3.811)
# trueskill.Rating(mu=13.494, sigma=3.811)
# ------
#
#
#
# trueskill.Rating(mu=36.521, sigma=3.802)
# trueskill.Rating(mu=13.479, sigma=3.802)
# ------
#
#
#
# trueskill.Rating(mu=36.536, sigma=3.793)
# trueskill.Rating(mu=13.464, sigma=3.793)
# ------
#
#
#
# trueskill.Rating(mu=36.550, sigma=3.785)
# trueskill.Rating(mu=13.450, sigma=3.785)
# ------
#
#
#
# trueskill.Rating(mu=36.564, sigma=3.776)
# trueskill.Rating(mu=13.436, sigma=3.776)
# ------
#
#
#
# trueskill.Rating(mu=36.577, sigma=3.768)
# trueskill.Rating(mu=13.423, sigma=3.768)
# ------
#
#
#
# trueskill.Rating(mu=36.591, sigma=3.760)
# trueskill.Rating(mu=13.409, sigma=3.760)
# ------
#
#
#
# trueskill.Rating(mu=36.604, sigma=3.752)
# trueskill.Rating(mu=13.396, sigma=3.752)
# ------
#
#
#
# trueskill.Rating(mu=36.617, sigma=3.744)
# trueskill.Rating(mu=13.383, sigma=3.744)
# ------
#
#
#
# trueskill.Rating(mu=36.629, sigma=3.737)
# trueskill.Rating(mu=13.371, sigma=3.737)
# ------
#
#
#
# trueskill.Rating(mu=36.642, sigma=3.729)
# trueskill.Rating(mu=13.358, sigma=3.729)
# ------
#
#
#
# trueskill.Rating(mu=36.654, sigma=3.722)
# trueskill.Rating(mu=13.346, sigma=3.722)
# ------
#
#
#
# trueskill.Rating(mu=36.666, sigma=3.715)
# trueskill.Rating(mu=13.334, sigma=3.715)
# ------
#
#
#
# trueskill.Rating(mu=36.677, sigma=3.708)
# trueskill.Rating(mu=13.323, sigma=3.708)
# ------
#
#
#
# trueskill.Rating(mu=36.689, sigma=3.701)
# trueskill.Rating(mu=13.311, sigma=3.701)
# ------
#
#
#
# trueskill.Rating(mu=36.700, sigma=3.695)
# trueskill.Rating(mu=13.300, sigma=3.695)
# ------
#
#
#
# trueskill.Rating(mu=36.711, sigma=3.688)
# trueskill.Rating(mu=13.289, sigma=3.688)
# ------
#
#
#
# trueskill.Rating(mu=36.722, sigma=3.682)
# trueskill.Rating(mu=13.278, sigma=3.682)
# ------
#
#
#
# trueskill.Rating(mu=36.733, sigma=3.675)
# trueskill.Rating(mu=13.267, sigma=3.675)
# ------
#
#
#
# trueskill.Rating(mu=36.743, sigma=3.669)
# trueskill.Rating(mu=13.257, sigma=3.669)
# ------
#
#
#
# trueskill.Rating(mu=36.753, sigma=3.663)
# trueskill.Rating(mu=13.247, sigma=3.663)
# ------
#
#
#
# trueskill.Rating(mu=36.764, sigma=3.657)
# trueskill.Rating(mu=13.236, sigma=3.657)
# ------
#
#
#
# trueskill.Rating(mu=36.774, sigma=3.651)
# trueskill.Rating(mu=13.226, sigma=3.651)
# ------
#
#
#
# trueskill.Rating(mu=36.783, sigma=3.645)
# trueskill.Rating(mu=13.217, sigma=3.645)
# ------
#
#
#
# trueskill.Rating(mu=36.793, sigma=3.640)
# trueskill.Rating(mu=13.207, sigma=3.640)
# ------
#
#
#
# trueskill.Rating(mu=36.803, sigma=3.634)
# trueskill.Rating(mu=13.197, sigma=3.634)
# ------
#
#
#
# trueskill.Rating(mu=36.812, sigma=3.629)
# trueskill.Rating(mu=13.188, sigma=3.629)
# ------
#
#
#
# trueskill.Rating(mu=36.821, sigma=3.623)
# trueskill.Rating(mu=13.179, sigma=3.623)
# ------
#
#
#
# trueskill.Rating(mu=36.830, sigma=3.618)
# trueskill.Rating(mu=13.170, sigma=3.618)
# ------
#
#
#
# trueskill.Rating(mu=36.839, sigma=3.613)
# trueskill.Rating(mu=13.161, sigma=3.613)
# ------
#
#
#
# trueskill.Rating(mu=36.848, sigma=3.608)
# trueskill.Rating(mu=13.152, sigma=3.608)
# ------
#
#
#
# trueskill.Rating(mu=36.857, sigma=3.603)
# trueskill.Rating(mu=13.143, sigma=3.603)
# ------
#
#
#
# trueskill.Rating(mu=36.866, sigma=3.598)
# trueskill.Rating(mu=13.134, sigma=3.598)
# ------
#
#
#
# trueskill.Rating(mu=36.874, sigma=3.593)
# trueskill.Rating(mu=13.126, sigma=3.593)
# ------
#
#
#
# trueskill.Rating(mu=36.883, sigma=3.588)
# trueskill.Rating(mu=13.117, sigma=3.588)
# ------
#
#
#
# trueskill.Rating(mu=36.891, sigma=3.584)
# trueskill.Rating(mu=13.109, sigma=3.584)
# ------
#
#
#
# trueskill.Rating(mu=36.899, sigma=3.579)
# trueskill.Rating(mu=13.101, sigma=3.579)
# ------
#
#
#
# trueskill.Rating(mu=36.907, sigma=3.574)
# trueskill.Rating(mu=13.093, sigma=3.574)
# ------
#
#
#
# trueskill.Rating(mu=36.915, sigma=3.570)
# trueskill.Rating(mu=13.085, sigma=3.570)
# ------
#
#
#
# trueskill.Rating(mu=36.923, sigma=3.566)
# trueskill.Rating(mu=13.077, sigma=3.566)
# ------
#
#
#
# trueskill.Rating(mu=36.931, sigma=3.561)
# trueskill.Rating(mu=13.069, sigma=3.561)
# ------
#
#
#
# trueskill.Rating(mu=36.938, sigma=3.557)
# trueskill.Rating(mu=13.062, sigma=3.557)
# ------
#
#
#
# trueskill.Rating(mu=36.946, sigma=3.553)
# trueskill.Rating(mu=13.054, sigma=3.553)
# ------
#
#
#
# trueskill.Rating(mu=36.953, sigma=3.549)
# trueskill.Rating(mu=13.047, sigma=3.549)
# ------
#
#
#
# trueskill.Rating(mu=36.961, sigma=3.544)
# trueskill.Rating(mu=13.039, sigma=3.544)
# ------

# %% [markdown]
# # reads evaluation data and treats it

# %%
import json

f = open('dump.json', 'r')

data = json.load(f)['official_test']
f.close()

# %%
ref = [
  'Eat less meat', 
  'Burn down all data centers',
  'Turn off appliances when not in use', 
  'Recycle more', 
  'Reshape our cities to be less car-dependent',
  'An all-encompassing high-rate carbon-tax',
  'Do nothing and just watch the world burn',
  'Hope for a deus ex machina'
]

# %%
ref = ['Educational tools about the effects and causes of climate change',
'Power aware computing',
'Electric vehicles',
'Turn off devices when not in use',
'Switch to renewable energy',
'Smart infrastructure',
'Reducing emissions',
'Design computers/electronics for disassembly/deconstruction',
'Reshape our cities to be less car-dependent',
'Implement a carbon tax',
'Remote work',
'Decentralized energy production and distribution systems',
'Disincentivize meat-based diets',
'Vote for climate-change oriented politicians',
'Cut on consumption']

# %% [markdown]
# ## Captures matches' data

# %%
matches = []

for key in data:
  if 'answers' in data[key]:
    if len(data[key]['answers']) > 0:
      for i in range(len(data[key]['answers'])):
        answer = data[key]['answers'][i]        
        p0 = answer['current_pair_of_indexes'][answer['selected_option_index']]
        if answer['selected_option_index'] == 0:
          p1 = answer['current_pair_of_indexes'][1]
        else:
          p1 = answer['current_pair_of_indexes'][0]
        matches.append((p0,p1))
        
print(matches)
# Out:
# [(6, 3), (2, 3), (4, 6), (0, 3), (7, 5), (9, 1), (14, 12), (4, 5), (9, 11), (14, 11), (0, 10), (6, 1), (8, 11), (5, 3), (9, 14), (8, 3), (14, 1), (10, 12), (4, 0), (14, 8), (14, 2), (12, 3), (2, 12), (13, 12), (2, 0), (4, 11), (2, 1), (10, 11), (14, 10), (10, 2), (0, 13), (8, 2), (10, 0), (5, 7), (11, 7), (14, 12), (3, 9), (0, 7), (8, 4), (6, 2), (6, 1), (3, 5), (6, 10), (12, 11), (10, 11), (8, 5), (10, 7), (3, 7), (3, 1), (3, 13), (8, 11), (14, 4), (14, 1), (11, 13), (5, 2), (2, 13), (0, 4), (3, 11), (5, 9), (7, 1), (6, 14), (9, 13), (11, 7), (6, 4), (14, 2), (7, 12), (14, 7), (14, 13), (8, 5), (0, 13), (10, 7), (14, 5), (9, 0), (0, 5), (6, 13), (14, 0), (8, 12), (9, 4), (14, 1), (6, 3), (0, 11), (6, 12), (14, 4), (0, 2), (3, 9), (7, 1), (2, 1), (1, 12), (3, 1), (3, 10), (0, 3), (0, 9), (4, 12), (13, 14), (0, 8), (14, 7), (14, 1), (8, 12), (0, 7), (4, 10), (6, 1), (8, 9), (5, 3), (5, 13), (6, 13), (10, 9), (4, 13), (11, 4), (6, 7), (2, 7), (0, 10), (10, 1), (6, 11), (10, 11), (2, 13), (3, 9), (8, 11), (9, 11), (4, 6), (14, 12), (9, 4), (6, 1), (1, 8), (8, 11), (1, 10), (6, 4), (9, 11), (12, 2), (6, 0), (11, 2), (4, 12), (7, 10), (3, 2), (14, 0), (10, 13), (1, 13), (9, 0), (14, 7), (7, 1), (1, 11), (3, 8), (3, 1), (5, 13), (11, 10), (7, 0), (14, 8), (14, 13), (7, 13), (11, 12), (12, 0), (1, 14), (8, 14), (5, 12), (13, 9), (11, 3), (2, 4), (9, 12), (6, 2), (0, 12), (4, 11), (0, 9), (10, 3), (12, 11), (10, 0), (2, 0), (4, 5), (10, 2), (1, 12), (1, 3), (5, 11), (7, 14), (0, 3), (11, 1), (12, 8), (6, 14), (8, 5), (10, 5), (6, 8), (4, 7), (0, 4), (4, 2), (11, 3), (4, 0), (4, 11), (9, 3), (14, 0), (7, 11), (4, 9), (12, 7), (12, 2), (8, 11), (10, 7), (14, 8), (0, 3), (10, 0), (1, 3), (11, 7), (1, 7), (3, 2), (1, 4), (9, 4), (14, 10), (10, 2), (11, 13), (0, 7), (11, 0), (4, 7), (5, 13), (12, 0), (1, 6), (11, 2), (5, 9), (4, 3), (8, 10), (3, 7), (14, 1), (0, 13), (14, 12), (12, 4), (6, 9), (8, 9), (14, 13), (2, 7), (1, 2), (9, 11), (6, 3), (11, 8), (4, 2), (13, 3), (13, 9), (9, 0), (11, 0), (6, 7), (9, 5), (2, 7), (4, 14), (4, 9), (10, 0), (7, 3), (14, 3), (9, 3), (1, 10), (13, 5), (10, 7), (9, 14), (6, 11), (4, 11), (14, 2), (10, 12), (10, 14), (5, 14), (5, 8), (13, 11), (8, 3), (7, 12), (3, 12), (1, 7), (1, 3), (6, 9), (0, 6), (6, 5), (2, 1), (6, 7), (14, 13), (2, 9), (4, 13), (2, 7), (2, 13), (4, 3), (10, 7), (1, 12), (0, 14), (11, 10), (2, 11), (5, 9), (4, 12), (11, 13), (5, 13), (11, 0), (6, 11), (6, 13), (8, 2), (5, 0), (5, 12), (7, 10), (2, 7), (3, 10), (14, 13), (9, 0), (4, 9), (8, 10), (1, 12), (2, 9), (5, 11), (6, 8), (1, 3), (0, 13), (11, 7), (14, 0), (6, 12), (2, 11), (6, 0), (5, 13), (4, 7), (7, 0), (1, 2), (6, 3), (2, 8), (4, 12), (4, 5), (4, 8), (14, 3), (4, 11), (3, 9), (2, 9), (6, 7), (5, 1), (11, 1), (12, 0), (9, 1), (13, 0), (14, 1), (4, 1), (7, 1), (4, 6), (12, 4), (5, 13), (14, 12), (10, 4), (11, 7), (12, 10), (12, 9), (8, 0), (8, 2), (12, 3), (8, 11), (8, 7), (8, 9), (11, 5), (10, 3), (14, 8), (4, 13), (13, 1), (6, 9), (0, 8), (13, 7), (13, 9), (9, 11), (4, 9), (2, 3), (3, 6), (5, 14), (0, 7), (5, 3), (2, 6), (9, 12), (4, 11), (13, 14), (7, 12), (4, 8), (10, 1), (2, 0), (13, 3), (4, 12), (10, 12), (5, 11), (2, 5), (0, 3), (4, 1), (4, 7), (10, 13), (8, 14), (10, 6)]

# %% [markdown]
# ## Sets up players

# %%
players = []

for i in range(len(ref)):
  p = trueskill.Rating()
  print(f"initial rating for {ref[i]}: {p}")
  players.append(p)
# Out:
# initial rating for Educational tools about the effects and causes of climate change: trueskill.Rating(mu=25.000, sigma=8.333)
# initial rating for Power aware computing: trueskill.Rating(mu=25.000, sigma=8.333)
# initial rating for Electric vehicles: trueskill.Rating(mu=25.000, sigma=8.333)
# initial rating for Turn off devices when not in use: trueskill.Rating(mu=25.000, sigma=8.333)
# initial rating for Switch to renewable energy: trueskill.Rating(mu=25.000, sigma=8.333)
# initial rating for Smart infrastructure: trueskill.Rating(mu=25.000, sigma=8.333)
# initial rating for Reducing emissions: trueskill.Rating(mu=25.000, sigma=8.333)
# initial rating for Design computers/electronics for disassembly/deconstruction: trueskill.Rating(mu=25.000, sigma=8.333)
# initial rating for Reshape our cities to be less car-dependent: trueskill.Rating(mu=25.000, sigma=8.333)
# initial rating for Implement a carbon tax: trueskill.Rating(mu=25.000, sigma=8.333)
# initial rating for Remote work: trueskill.Rating(mu=25.000, sigma=8.333)
# initial rating for Decentralized energy production and distribution systems: trueskill.Rating(mu=25.000, sigma=8.333)
# initial rating for Disincentivize meat-based diets: trueskill.Rating(mu=25.000, sigma=8.333)
# initial rating for Vote for climate-change oriented politicians: trueskill.Rating(mu=25.000, sigma=8.333)
# initial rating for Cut on consumption: trueskill.Rating(mu=25.000, sigma=8.333)

# %% [markdown]
# ## Matches per se

# %%
for i in range(len(matches)):
  p0_i = matches[i][0]
  p1_i = matches[i][1]
  players[p0_i], players[p1_i] = trueskill.rate_1vs1(players[p0_i], players[p1_i])

# %% [markdown]
# ## Result

# %%
players.sort(key=lambda x: x.mu, reverse=True)


# this is wrong! 
for i in range(len(players)):  
  print(f"final rating for ‘{ref[i]}’: {players[i]}")
# Out:
# final rating for ‘Educational tools about the effects and causes of climate change’: trueskill.Rating(mu=29.492, sigma=1.647)
# final rating for ‘Power aware computing’: trueskill.Rating(mu=28.457, sigma=1.210)
# final rating for ‘Electric vehicles’: trueskill.Rating(mu=26.926, sigma=1.362)
# final rating for ‘Turn off devices when not in use’: trueskill.Rating(mu=26.327, sigma=1.395)
# final rating for ‘Switch to renewable energy’: trueskill.Rating(mu=26.165, sigma=1.381)
# final rating for ‘Smart infrastructure’: trueskill.Rating(mu=25.824, sigma=1.274)
# final rating for ‘Reducing emissions’: trueskill.Rating(mu=24.528, sigma=1.247)
# final rating for ‘Design computers/electronics for disassembly/deconstruction’: trueskill.Rating(mu=23.369, sigma=1.289)
# final rating for ‘Reshape our cities to be less car-dependent’: trueskill.Rating(mu=23.300, sigma=1.150)
# final rating for ‘Implement a carbon tax’: trueskill.Rating(mu=23.232, sigma=1.205)
# final rating for ‘Remote work’: trueskill.Rating(mu=22.811, sigma=1.175)
# final rating for ‘Decentralized energy production and distribution systems’: trueskill.Rating(mu=21.530, sigma=1.318)
# final rating for ‘Disincentivize meat-based diets’: trueskill.Rating(mu=21.406, sigma=1.369)
# final rating for ‘Vote for climate-change oriented politicians’: trueskill.Rating(mu=21.267, sigma=1.222)
# final rating for ‘Cut on consumption’: trueskill.Rating(mu=20.153, sigma=1.255)

# %% [markdown]
# # Shuffles results

# %%
def init_player_rankings():
  temp_rankings = []

  for i in range(len(ref)):
    p = trueskill.Rating()
    temp_rankings.append(p)

  return temp_rankings

# %%
import random
from statistics import stdev, mean

p_list = []
stdevs = [[],[]]

for i in range(200):
    random.shuffle(matches)
    temp_players = init_player_rankings()
    for j in range(len(matches)):
      p0_i = matches[j][0]
      p1_i = matches[j][1]
      temp_players[p0_i], temp_players[p1_i] = trueskill.rate_1vs1(temp_players[p0_i], temp_players[p1_i])

    p_list.append(temp_players) 
    
    if i > 0:
      temp_p = []
      for k in range(len(ref)):
        temp_p.append(stdev([p_list[j][k].mu for j in range(i+1)]))
      stdevs[0].append(i)
      stdevs[1].append(stdev(temp_p))
      #print(round(statistics.stdev(temp_p),5))

# %%
import matplotlib.pyplot as plt

plt.plot(stdevs[0],stdevs[1])
plt.ylabel('std dev of std devs')
plt.xlabel('rounds')
plt.show()

# %%
from statistics import mean

avg_mus = []
avg_sigmas = []
for i in range(len(ref)):
  avg_mus.append(mean([p_list[j][i].mu for j in range(len(p_list))]))  
  avg_sigmas.append(mean([p_list[j][i].sigma for j in range(len(p_list))]))
  
print(avg_mus)
print(avg_sigmas)
# Out:
# [24.363118351377405, 23.256796637074782, 25.181074349262378, 22.325226975869956, 28.58496487706572, 26.19480907603502, 30.844207189233163, 21.3384162547075, 27.467938274350736, 24.164118338093722, 26.372184678695778, 23.133340439586256, 22.02369098400218, 21.414344926768628, 28.488907208779505]
# [1.134067688825905, 1.219180441033287, 1.228485704164791, 1.1865972223584564, 1.2160975873562383, 1.360654121668238, 1.5016412311640923, 1.2292331557864735, 1.3213761907848511, 1.2094818017410969, 1.2628721729950043, 1.1524717211107391, 1.2705418729845224, 1.3318439044676942, 1.246207452491854]

# %%
rebuilt_ranking = []
for i in range(len(ref)):
  rebuilt_ranking.append({
      'strat': ref[i],
      'mu': avg_mus[i],
      'sigma': avg_sigmas[i]
    })

rebuilt_ranking.sort(key=lambda x: x['mu'], reverse=True)
for i in range(len(ref)):
  print(rebuilt_ranking[i])
# Out:
# {'strat': 'Reducing emissions', 'mu': 30.844207189233163, 'sigma': 1.5016412311640923}
# {'strat': 'Switch to renewable energy', 'mu': 28.58496487706572, 'sigma': 1.2160975873562383}
# {'strat': 'Cut on consumption', 'mu': 28.488907208779505, 'sigma': 1.246207452491854}
# {'strat': 'Reshape our cities to be less car-dependent', 'mu': 27.467938274350736, 'sigma': 1.3213761907848511}
# {'strat': 'Remote work', 'mu': 26.372184678695778, 'sigma': 1.2628721729950043}
# {'strat': 'Smart infrastructure', 'mu': 26.19480907603502, 'sigma': 1.360654121668238}
# {'strat': 'Electric vehicles', 'mu': 25.181074349262378, 'sigma': 1.228485704164791}
# {'strat': 'Educational tools about the effects and causes of climate change', 'mu': 24.363118351377405, 'sigma': 1.134067688825905}
# {'strat': 'Implement a carbon tax', 'mu': 24.164118338093722, 'sigma': 1.2094818017410969}
# {'strat': 'Power aware computing', 'mu': 23.256796637074782, 'sigma': 1.219180441033287}
# {'strat': 'Decentralized energy production and distribution systems', 'mu': 23.133340439586256, 'sigma': 1.1524717211107391}
# {'strat': 'Turn off devices when not in use', 'mu': 22.325226975869956, 'sigma': 1.1865972223584564}
# {'strat': 'Disincentivize meat-based diets', 'mu': 22.02369098400218, 'sigma': 1.2705418729845224}
# {'strat': 'Vote for climate-change oriented politicians', 'mu': 21.414344926768628, 'sigma': 1.3318439044676942}
# {'strat': 'Design computers/electronics for disassembly/deconstruction', 'mu': 21.3384162547075, 'sigma': 1.2292331557864735}
